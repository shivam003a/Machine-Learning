# %% [markdown]
# <a href="https://colab.research.google.com/github/shivam003a/Machine-Learning/blob/main/Day_5_Part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
profit = [10,20,30,25]
label = ['Amazon', 'Flipkart', 'Snapdeal', 'Tata']

colors = ['red', 'magenta', 'green', 'purple']
explod = [0.1, 0.2, 0, 0]

plt.pie(profit, colors=colors, labels = label, autopct = '%.2f', explode = explod)
plt.show()
